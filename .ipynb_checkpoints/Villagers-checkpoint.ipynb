# %%
# Dependencies for analysis
import numpy as np 
import pandas as pd 

# Dependencies for graphing
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns

# %%
# Read in .csv file
villager_info=pd.read_csv('Resources/villagers.csv')

# %%
# Make a dataframe
villagers_df=pd.DataFrame(villager_info)

villagers_df
# Out:
#          Name    Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul    sidekick
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr     snuffle
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun    it'sa me
# ..        ...        ...     ...         ...        ...      ...         ...
# 386    Winnie      Horse  Female       Peppy    Fashion   31-Jan      hay-OK
# 387  Wolfgang       Wolf    Male      Cranky  Education   25-Nov     snarrrl
# 388      Yuka      Koala  Female      Snooty    Fashion   20-Jul     tsk tsk
# 389      Zell       Deer    Male        Smug      Music    7-Jun       pronk
# 390    Zucker    Octopus    Male        Lazy     Nature    8-Mar       bloop
#
# ...

# %%
# Find NaN and drop it
villagers_df.dropna()
# Out:
#          Name    Species  Gender Personality      Hobby Birthday Catchphrase  \
# 0     Admiral       Bird    Male      Cranky     Nature   27-Jan     aye aye
# 1     Agent S   Squirrel  Female       Peppy    Fitness    2-Jul    sidekick
# 2       Agnes        Pig  Female  Big Sister       Play   21-Apr     snuffle
# 3          Al    Gorilla    Male        Lazy    Fitness   18-Oct     ayyyeee
# 4     Alfonso  Alligator    Male        Lazy       Play    9-Jun    it'sa me
# ..        ...        ...     ...         ...        ...      ...         ...
# 386    Winnie      Horse  Female       Peppy    Fashion   31-Jan      hay-OK
# 387  Wolfgang       Wolf    Male      Cranky  Education   25-Nov     snarrrl
# 388      Yuka      Koala  Female      Snooty    Fashion   20-Jul     tsk tsk
# 389      Zell       Deer    Male        Smug      Music    7-Jun       pronk
# 390    Zucker    Octopus    Male        Lazy     Nature    8-Mar       bloop
#
# ...

# %%
# Drop columns that are not needed
villagers_df.drop(columns=['Name', 'Gender', 'Hobby', 'Catchphrase', 'Style 1', 'Style 2', 'Color 1', 'Color 2',
                          'Wallpaper', 'Flooring', 'Furniture List', 'Filename', 'Unique Entry ID', 'Birthday'], inplace=True)

villagers_df.head()
# Out:
#      Species Personality  Favorite Song
# 0       Bird      Cranky     Steep Hill
# 1   Squirrel       Peppy  Go K.K. Rider
# 2        Pig  Big Sister     K.K. House
# 3    Gorilla        Lazy  Go K.K. Rider
# 4  Alligator        Lazy    Forest Life

# %%
# How many of each species
species_list=villagers_df.value_counts('Species')

species_count_df=pd.DataFrame(species_list)

species_count_df.head()
# Out:
#            0
# Species
# Cat       23
# Rabbit    20
# Squirrel  18
# Frog      18
# Duck      17

# %%
# Rename 0 column
species_count_df.rename(columns={0:'Count of Species'}, inplace=True)

species_count_df.head()
# Out:
#           Count of Species
# Species
# Cat                     23
# Rabbit                  20
# Squirrel                18
# Frog                    18
# Duck                    17

# %%
# Plot count of each species
plt.figure(figsize=(50,50))

sns.color_palette('rocket', as_cmap=True)

sns.barplot(x=species_count_df.index, y='Count of Species', data=species_count_df,
           palette='rocket')

plt.title('Species of Villagers in Animal Crossing', fontsize=75)

plt.xlabel('Species', fontsize=70)

plt.ylabel('Count of Species', fontsize=70)

plt.xticks(rotation=70, fontsize=55)

plt.yticks(fontsize=50)
# Out:
# (array([ 0.,  5., 10., 15., 20., 25.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
# Type of personalities
villagers_df.head()

personality_list=villagers_df.value_counts('Personality')

personality_list
# Out:
# Personality
# Lazy          60
# Normal        59
# Cranky        55
# Jock          55
# Snooty        55
# Peppy         49
# Smug          34
# Big Sister    24
# dtype: int64

# %%
# Create a dataframe
personality_df=pd.DataFrame(personality_list)

personality_df.head()
# Out:
#               0
# Personality
# Lazy         60
# Normal       59
# Cranky       55
# Jock         55
# Snooty       55

# %%
# Rename columns
personality_df.rename(columns={0:'Count of Personalities'}, inplace=True)

personality_df.head()
# Out:
#              Count of Personalities
# Personality
# Lazy                             60
# Normal                           59
# Cranky                           55
# Jock                             55
# Snooty                           55

# %%
# Barchart for personalities
plt.figure(figsize=(20,15),dpi=80)

sns.barplot(x=personality_df.index, y='Count of Personalities', data=personality_df,
           palette='magma')

plt.title('Personalities of Villagers in Animal Crossing', fontsize=50)

plt.xlabel('Personalities', fontsize=40)

plt.ylabel('Count of Personalities', fontsize=40)

plt.xticks(rotation=60, fontsize=25)

plt.yticks(fontsize=25)
# Out:
# (array([ 0., 10., 20., 30., 40., 50., 60., 70.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])

# %%
villagers_df.head()
# Out:
#      Species Personality  Favorite Song
# 0       Bird      Cranky     Steep Hill
# 1   Squirrel       Peppy  Go K.K. Rider
# 2        Pig  Big Sister     K.K. House
# 3    Gorilla        Lazy  Go K.K. Rider
# 4  Alligator        Lazy    Forest Life

# %%
# Favorite songs for villagers
favorite_songs=villagers_df.value_counts('Favorite Song')

favorite_songs
# Out:
# Favorite Song
# Forest Life      15
# K.K. Soul        12
# K.K. Cruisin'    11
# K.K. Stroll      10
# K.K. Disco        9
#                  ..
# K.K. Mambo        1
# K.K. Aria         1
# The K. Funk       1
# K.K. Parade       1
# K.K. Salsa        1
# Length: 89, dtype: int64

# %%
# Make dataframe for villager's favorite songs
favorite_songs_df=pd.DataFrame(favorite_songs)

favorite_songs_df.head()
# Out:
#                 0
# Favorite Song
# Forest Life    15
# K.K. Soul      12
# K.K. Cruisin'  11
# K.K. Stroll    10
# K.K. Disco      9

# %%
# Rename column
favorite_songs_df.rename(columns={0:'Count of Favorite Songs'}, inplace=True)

favorite_songs_df.head()
# Out:
#                Count of Favorite Songs
# Favorite Song
# Forest Life                         15
# K.K. Soul                           12
# K.K. Cruisin'                       11
# K.K. Stroll                         10
# K.K. Disco                           9

# %%
# Bar chart
plt.figure(figsize=(35,25), dpi=80)

sns.barplot(x=favorite_songs_df.index, y='Count of Favorite Songs', data=favorite_songs_df,
           palette='magma')

plt.title('Favorite Songs of Villagers in Animal Crossing', fontsize=80)

plt.xlabel('Song Title', fontsize=50)

plt.ylabel('Count of Favorite Song', fontsize=50)

plt.xticks(rotation=90, fontsize=25)

plt.yticks(fontsize=35)
# Out:
# (array([ 0.,  2.,  4.,  6.,  8., 10., 12., 14., 16.]),
#  [Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, ''),
#   Text(0, 0, '')])
